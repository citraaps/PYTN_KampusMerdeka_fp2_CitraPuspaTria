# %% [markdown]
# ![if1l4k3xxg44dkg2p.png](attachment:if1l4k3xxg44dkg2p.png)

# %% [markdown]
# # FINAL PROJECT 2 : LOGISTIC REGRESSION AND SVM

# %% [markdown]
# ## Introduction

# %% [markdown]
# ### Members

# %% [markdown]
# 1. Citra Puspa Tria
# 2. Fadhilah Gustriandini
# 3. Nabilla Yolanda Paramitha

# %% [markdown]
# ### Abstract
#
# Cuaca adalah keadaan udara di atmosfer pada waktu dan tempat tertentu yang sifatnya tidak menentu dan berubah-ubah. Berbagai faktor akan menentukan cuaca yang terjadi di suatu waktu dan tempat. Adanya pengaruh ini membuat cuaca dapat berubah-ubah. Penilaian terhadap kategori cuaca dapat dinyatakan dengan memperhatikan suhu udara, jumlah tutupan awan, kelembapan, kecepatan angin, dan juga beberapa faktor lainnya. Hal inilah yang nantinya bisa digunakan dalam prediksi cuaca, contohnya seperti prediksi cuaca hujan.
#
# Australia memiliki 3 wilayah iklim, yaitu iklim tropis, subtropis, laut sedang, dan gurun. Iklim yang berbeda dapat menyebabkan beberapa wilayah memeiliki musim yang berbeda. Kemudian hal ini juga akan mengakibatkan cuaca dari setiap wilayah pada suatu waktu juga akan berbeda. Dengan beberapa faktor yang mempengaruhi cuaca, akan diprediksi apakah akan terjadi hujan di esok hari menggunakan regresi logistik dan Support Vector Machine (SVM) utuk mendapatkan model yang sesuai dengan data tersebut.

# %% [markdown]
# ### Data
#
# Dataset yang digunakan pada project ini didapat dari website Kaggle (https://www.kaggle.com/jsphyg/weather-dataset-rattle-package) mengenai data hujan harian selama 10 tahun di Australia. Dataset ini memiliki 23 atribut. Kolom RainTomorrow adalah target variable yang akan prediksi. Jika “Yes” maka besok harinya disana hujan 1mm atau lebih.
#
# Berikut disajikan keterangan dari setiap kolom :
# 1. Date - tanggal hari itu
# 2. Location - lokasi, nama kota di Australia
# 3. MinTemp - temperatur terendah hari itu dalam celcius
# 4. MaxTemp - temperatur tertinggi hari itu dalam celcius
# 5. Rainfall - jumlah curah hujan hari itu dalam mm
# 6. Evaporation - jumlah evaporasi dalam mm dari Class A pan selama 24 jam sebelum jam 9 pagi hari itu
# 7. Sunshine - jumlah jam hari itu cerah dengan cahaya matahari
# 8. WindGustDir - arah kecepatan angin yang paling tinggi selama 24 jam sebelum jam 12 malam hari itu
# 9. WindGustSpeed - kecepatan angin yang paling tinggi dalam km/jam selama 24 jam sebelum jam 12 malam hari itu
# 10. WindDir9am - arah angin jam 9 pagi
# 11. WindDir3pm - arah angin jam 3 sore
# 12. WindSpeed9am - kecepatan angin jam 9 pagi dalam km/jam dihitung dari rata-rata kecepatan angin 10 menit sebelum jam 3 sore
# 13. WindSpeed3pm - kecepatan angin jam 3 sore dalam km/jam dihitung dari rata-rata kecepatan angin 10 menit sebelum jam 3 sore
# 14. Humidity9am - humiditas jam 9 pagi dalam persen
# 15. Humidity3pm - humiditas jam 3 sore dalam persen
# 16. Pressure9am - tekanan udara jam 9 pagi dalam hpa
# 17. Pressure3pm - tekanan udara jam 3 sore dalam hpa
# 18. Cloud9am - persentase langit yang tertutup awan jam 9 pagi. dihitung dalam oktas, unit ⅛, menghitung berapa unit ⅛ dari langit yang tertutup awan. Jika 0, langit cerah, jika 8, langit sepenuhnya tertutup awan.
# 19. Cloud3pm - persentase langit yang tertutup awan jam 3 sore
# 20. Temp9am - temperatur jam 9 pagi dalam celcius
# 21. Temp3pm - temperatur jam 3 sore dalam celcius
# 22. RainToday - apakah hari ini hujan: jika curah hujan 24 jam sebelum jam 9 pagi melebihi 1mm, maka nilai ini adalah 1, jika tidak nilai nya 0
# 23. RainTomorrow - variable yang akan di prediksi
#
#
# ### Objective
# Final Project 2 ini dibuat guna mengevaluasi konsep Logistic Regression dan SVM sebagai berikut:
# - Mampu memahami konsep Classification dengan Logistic Regression dan SVM
# - Mampu mempersiapkan data untuk digunakan dalam model Logistic Regression dan SVM
# - Mampu mengimplementasikan Logistic Regression dan SVM untuk membuat prediksi

# %% [markdown]
# ## Import Libraries

# %%
# Library For DataFrame
import pandas as pd
import numpy as np
import pandas_profiling

# Library for datetime
import datetime
import calendar

# Librart for visualization
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import plotly.express as px

# Library for analysis
import scipy
from sklearn import preprocessing
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn import svm
from sklearn.metrics import accuracy_score,f1_score, precision_score, recall_score
from sklearn.metrics import max_error,mean_absolute_error,median_absolute_error,mean_squared_error,r2_score
import pickle
from sklearn.feature_selection import f_regression
from sklearn.feature_selection import SelectKBest
from sklearn.pipeline import Pipeline
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import GridSearchCV,ShuffleSplit

# me-non aktifkan peringatan pada python
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Data Loading

# %% [markdown]
# ### Import Dataset

# %%
# Dilakukan load dataset menggunakan pandas
data = pd.read_csv(r"~/datasets/weatherAUS.csv")
pd.set_option("display.max.columns", None)

# %%
# Akan dilihat 10 baris teratas dari dataset menggunakan fungsi head()
data.head(10)
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# 5  2008-12-06   Albury     14.6     29.7       0.2          NaN       NaN
# 6  2008-12-07   Albury     14.3     25.0       0.0          NaN       NaN
# 7  2008-12-08   Albury      7.7     26.7       0.0          NaN       NaN
# 8  2008-12-09   Albury      9.7     31.9       0.0          NaN       NaN
# 9  2008-12-10   Albury     13.1     30.1       1.4          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  \
# 0           W           44.0          W        WNW          20.0
# ...

# %%
# Akan dilihat 10 baris terbawah dari dataset menggunakan fungsi tail()
data.tail(10)
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 145450  2017-06-16    Uluru      5.2     24.3       0.0          NaN
# 145451  2017-06-17    Uluru      6.4     23.4       0.0          NaN
# 145452  2017-06-18    Uluru      8.0     20.7       0.0          NaN
# 145453  2017-06-19    Uluru      7.4     20.6       0.0          NaN
# 145454  2017-06-20    Uluru      3.5     21.8       0.0          NaN
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am WindDir3pm  \
# 145450       NaN           E           24.0         SE          E
# 145451       NaN         ESE           31.0          S        ESE
# ...

# %% [markdown]
# ### Type of Data

# %%
# menggunakan metode info() untuk mendapatkan informasi dasar tentang kerangka data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %% [markdown]
# ### List of Columns

# %%
# menggunakan parameter .columns.values untuk mendapatkan list header kolom
data.columns.values
# Out:
# array(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall',
#        'Evaporation', 'Sunshine', 'WindGustDir', 'WindGustSpeed',
#        'WindDir9am', 'WindDir3pm', 'WindSpeed9am', 'WindSpeed3pm',
#        'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm',
#        'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm', 'RainToday',
#        'RainTomorrow'], dtype=object)

# %% [markdown]
# ### Index

# %%
# Menggunakan parameter .index untuk mendapatkan daftar indeks
data.index.values
# Out:
# array([     0,      1,      2, ..., 145457, 145458, 145459], dtype=int64)

# %% [markdown]
# ### Number of Rows and Columns

# %%
# Menggunakan parameter .shape untuk mengetahui jumlah baris dan kolom pada dataset
data.shape
# Out:
# (145460, 23)

# %% [markdown]
# Dataset ini memiliki baris yang berjumlah 145460 dan kolom yang berjumlah 23

# %%
# Menghitung jumlah nilai unik pada setiap kolom
data.nunique()
# Out:
# Date             3436
# Location           49
# MinTemp           389
# MaxTemp           505
# Rainfall          681
# Evaporation       358
# Sunshine          145
# WindGustDir        16
# WindGustSpeed      67
# WindDir9am         16
# WindDir3pm         16
# WindSpeed9am       43
# WindSpeed3pm       44
# Humidity9am       101
# Humidity3pm       101
# Pressure9am       546
# Pressure3pm       549
# Cloud9am           10
# Cloud3pm           10
# Temp9am           441
# Temp3pm           502
# RainToday           2
# RainTomorrow        2
# dtype: int64

# %% [markdown]
# ### Missing Values

# %%
# Memeriksa apakah terdapat missing value pada dataset
data.isna().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
# Membuat visualisasi missing value
data.isna().sum().plot.bar()
plt.show()

# %% [markdown]
# Dari plot di atas dapat dilihat bahwa variable Sunshine, Evaporation, Cloud3pm, dan Cloud9am adalah fitur dengan jumlah missing value tertinggi

# %%
# Melihat persentase dari jumlah missing values pada setiap kolom
data_miss = pd.DataFrame({"Missing_Value":data.isna().sum(), 
                          "Percent":(data.isna().sum()/data.shape[0])*100})
data_miss
# Out:
#                Missing_Value    Percent
# Date                       0   0.000000
# Location                   0   0.000000
# MinTemp                 1485   1.020899
# MaxTemp                 1261   0.866905
# Rainfall                3261   2.241853
# Evaporation            62790  43.166506
# Sunshine               69835  48.009762
# WindGustDir            10326   7.098859
# WindGustSpeed          10263   7.055548
# WindDir9am             10566   7.263853
# WindDir3pm              4228   2.906641
# WindSpeed9am            1767   1.214767
# WindSpeed3pm            3062   2.105046
# Humidity9am             2654   1.824557
# Humidity3pm             4507   3.098446
# Pressure9am            15065  10.356799
# Pressure3pm            15028  10.331363
# Cloud9am               55888  38.421559
# Cloud3pm               59358  40.807095
# Temp9am                 1767   1.214767
# Temp3pm                 3609   2.481094
# RainToday               3261   2.241853
# ...

# %% [markdown]
# Karena persentase  missing value > 30, drop fitur.

# %%
# Menghapus kolom yang memiliki missing values dengan persentase lebih dari 30%
data_clean1 = data.drop(['Evaporation','Sunshine','Cloud9am','Cloud3pm'],axis=1)
# menunjukkan 5 data teratas
data_clean1.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall WindGustDir  WindGustSpeed  \
# 0  2008-12-01   Albury     13.4     22.9       0.6           W           44.0
# 1  2008-12-02   Albury      7.4     25.1       0.0         WNW           44.0
# 2  2008-12-03   Albury     12.9     25.7       0.0         WSW           46.0
# 3  2008-12-04   Albury      9.2     28.0       0.0          NE           24.0
# 4  2008-12-05   Albury     17.5     32.3       1.0           W           41.0
#
#   WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# 0          W        WNW          20.0          24.0         71.0         22.0
# 1        NNW        WSW           4.0          22.0         44.0         25.0
# 2          W        WSW          19.0          26.0         38.0         30.0
# 3         SE          E          11.0           9.0         45.0         16.0
# 4        ENE         NW           7.0          20.0         82.0         33.0
#
# ...

# %%
# melihat data unik dari kolom WindDir9am
data['WindDir9am'].unique()
# Out:
# array(['W', 'NNW', 'SE', 'ENE', 'SW', 'SSE', 'S', 'NE', nan, 'SSW', 'N',
#        'WSW', 'ESE', 'E', 'NW', 'WNW', 'NNE'], dtype=object)

# %%
# Melihat statistika deskriptif dari setiap kolom
data_clean1.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall  WindGustSpeed  \
# count  143975.000000  144199.000000  142199.000000  135197.000000
# mean       12.194034      23.221348       2.360918      40.035230
# std         6.398495       7.119049       8.478060      13.607062
# min        -8.500000      -4.800000       0.000000       6.000000
# 25%         7.600000      17.900000       0.000000      31.000000
# 50%        12.000000      22.600000       0.000000      39.000000
# 75%        16.900000      28.200000       0.800000      48.000000
# max        33.900000      48.100000     371.000000     135.000000
#
#         WindSpeed9am   WindSpeed3pm    Humidity9am    Humidity3pm  \
# count  143693.000000  142398.000000  142806.000000  140953.000000
# mean       14.043426      18.662657      68.880831      51.539116
# std         8.915375       8.809800      19.029164      20.795902
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
# melihat median dari setiap kolom
data_clean1[:].median()
# Out:
# MinTemp            12.0
# MaxTemp            22.6
# Rainfall            0.0
# WindGustSpeed      39.0
# WindSpeed9am       13.0
# WindSpeed3pm       19.0
# Humidity9am        70.0
# Humidity3pm        52.0
# Pressure9am      1017.6
# Pressure3pm      1015.2
# Temp9am            16.7
# Temp3pm            21.1
# dtype: float64

# %%
# Fill MinTemp dan MaxTemp menggunakan median
data_clean1['MinTemp']=data_clean1['MinTemp'].fillna(data_clean1['MinTemp'].median())
data_clean1['MaxTemp']=data_clean1['MaxTemp'].fillna(data_clean1['MaxTemp'].median())

# Fill Rainfall menggunakan median
data_clean1['Rainfall']=data_clean1['Rainfall'].fillna(data_clean1['Rainfall'].median())

# Fill WindGustSpeed menggunakan median
data_clean1['WindGustSpeed']=data_clean1['WindGustSpeed'].fillna(data_clean1['WindGustSpeed'].median())

# Fill WindSpeed9am dan WindSpeed3pm menggunakan median
data_clean1['WindSpeed9am']=data_clean1['WindSpeed9am'].fillna(data_clean1['WindSpeed9am'].median())
data_clean1['WindSpeed3pm']=data_clean1['WindSpeed3pm'].fillna(data_clean1['WindSpeed3pm'].median())

# Fill Humidity9am dan Humidity3pm menggunakan median
data_clean1['Humidity9am']=data_clean1['Humidity9am'].fillna(data_clean1['Humidity9am'].median())
data_clean1['Humidity3pm']=data_clean1['Humidity3pm'].fillna(data_clean1['Humidity3pm'].median())

# Fill Pressure9am dan Pressure3pm menggunakan median
data_clean1['Pressure9am']=data_clean1['Pressure9am'].fillna(data_clean1['Pressure9am'].median())
data_clean1['Pressure3pm']=data_clean1['Pressure3pm'].fillna(data_clean1['Pressure3pm'].median())

# Fill Temp9am dan Temp3pm menggunakan median
data_clean1['Temp9am']=data_clean1['Temp9am'].fillna(data_clean1['Temp9am'].median())
data_clean1['Temp3pm']=data_clean1['Temp3pm'].fillna(data_clean1['Temp3pm'].median())

# %%
# Memeriksa jumlah missing value pada dataset
data_clean1.isna().sum()
# Out:
# Date                 0
# Location             0
# MinTemp              0
# MaxTemp              0
# Rainfall             0
# WindGustDir      10326
# WindGustSpeed        0
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am         0
# WindSpeed3pm         0
# Humidity9am          0
# Humidity3pm          0
# Pressure9am          0
# Pressure3pm          0
# Temp9am              0
# Temp3pm              0
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
# Menghapus missing values yang berada di irisan kolom RainToday dan RainTomorrow
data_clean1.dropna(subset=['RainToday','RainTomorrow'], inplace=True)
#Melihat total baris dan kolom pada data
data_clean1.shape
# Out:
# (140787, 19)

# %%
# Menghapus missing value pada kolom
data_clean1.dropna(axis=0, inplace=True)
# Memeriksa jumlah missing value pada dataset
data_clean1.isna().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# dtype: int64

# %%
# menunjukkan 5 data teratas dari dataset
data_clean1.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall WindGustDir  WindGustSpeed  \
# 0  2008-12-01   Albury     13.4     22.9       0.6           W           44.0
# 1  2008-12-02   Albury      7.4     25.1       0.0         WNW           44.0
# 2  2008-12-03   Albury     12.9     25.7       0.0         WSW           46.0
# 3  2008-12-04   Albury      9.2     28.0       0.0          NE           24.0
# 4  2008-12-05   Albury     17.5     32.3       1.0           W           41.0
#
#   WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# 0          W        WNW          20.0          24.0         71.0         22.0
# 1        NNW        WSW           4.0          22.0         44.0         25.0
# 2          W        WSW          19.0          26.0         38.0         30.0
# 3         SE          E          11.0           9.0         45.0         16.0
# 4        ENE         NW           7.0          20.0         82.0         33.0
#
# ...

# %% [markdown]
# ## Data Exploration

# %%
# Membuat dataframe baru : data_copy
data_copy = data_clean1.copy()

# Menunjukkan 5 data teratas
data_copy.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall WindGustDir  WindGustSpeed  \
# 0  2008-12-01   Albury     13.4     22.9       0.6           W           44.0
# 1  2008-12-02   Albury      7.4     25.1       0.0         WNW           44.0
# 2  2008-12-03   Albury     12.9     25.7       0.0         WSW           46.0
# 3  2008-12-04   Albury      9.2     28.0       0.0          NE           24.0
# 4  2008-12-05   Albury     17.5     32.3       1.0           W           41.0
#
#   WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# 0          W        WNW          20.0          24.0         71.0         22.0
# 1        NNW        WSW           4.0          22.0         44.0         25.0
# 2          W        WSW          19.0          26.0         38.0         30.0
# 3         SE          E          11.0           9.0         45.0         16.0
# 4        ENE         NW           7.0          20.0         82.0         33.0
#
# ...

# %%
# Melihat statistika deskriptif dari data menggunakan fungsi describe()
data_copy.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall  WindGustSpeed  \
# count  123710.000000  123710.000000  123710.000000  123710.000000
# mean       12.413776      23.474582       2.375661      40.685280
# std         6.366799       7.205915       8.528039      13.388636
# min        -8.500000      -4.800000       0.000000       7.000000
# 25%         7.800000      18.100000       0.000000      31.000000
# 50%        12.200000      23.000000       0.000000      39.000000
# 75%        17.000000      28.600000       0.800000      48.000000
# max        33.900000      48.100000     367.600000     135.000000
#
#         WindSpeed9am   WindSpeed3pm    Humidity9am    Humidity3pm  \
# count  123710.000000  123710.000000  123710.000000  123710.000000
# mean       15.011689      19.174578      67.673470      50.862574
# std         8.307285       8.571039      18.976358      20.839815
# min         2.000000       2.000000       0.000000       0.000000
# ...

# %% [markdown]
# Dari perolehan di atas, dapat diambil informasi sebagai berikut :
# - Rata- rata temperatur paling rendah dalam satu hari adalah 12.413776 derajat celcius, sedangkan temperatur paling tinggi memiliki rata - rata sebesar 23.474582 derajat celcius.
# - Temperatur pada pukul 9 pagi dan 3 sore memiliki perbedaan yang sangat kecil, sehingga dapat dikatakan temperatur sepanjang hari cenderung sama.
# - Rata-rata curah hujan yang terjadi sebesar 8.528039 mm dan curah hujan paling tinggi dapat mencapai 367.6 mm.
# - Kelembaban udara dan tekanan udara pada pukul 3 sore cenderung lebih rendah daripada kelembaban dan tekanan udara pada pukul 9 pagi.
# - Kecepatan angin pada pukul 9 pagi cenderung lebih rendah daripada kecepatan angin pada pukul 9 pagi.
# - kecepatan angin yang paling tinggi selama 24 jam sebelum jam 12 malam hari itu berada pada rentang 7 km/jam sampai dengan 135 km/jam, dan memiliki nilai rata - rata sebesar 40.685280 km/jam.

# %%
# melakukan label encoding
le = LabelEncoder()
data_copy['Location']=le.fit_transform(data_copy['Location'])
data_copy['WindGustDir']=le.fit_transform(data_copy['WindGustDir'])
data_copy['WindDir9am']=le.fit_transform(data_copy['WindDir9am'])
data_copy['WindDir3pm']=le.fit_transform(data_copy['WindDir3pm'])
data_copy['RainToday']=le.fit_transform(data_copy['RainToday'])
data_copy['RainTomorrow']=le.fit_transform(data_copy['RainTomorrow'])

# %%
# menunjukkan 5 data teratas
data_copy.head()
# Out:
#          Date  Location  MinTemp  MaxTemp  Rainfall  WindGustDir  \
# 0  2008-12-01         1     13.4     22.9       0.6           13
# 1  2008-12-02         1      7.4     25.1       0.0           14
# 2  2008-12-03         1     12.9     25.7       0.0           15
# 3  2008-12-04         1      9.2     28.0       0.0            4
# 4  2008-12-05         1     17.5     32.3       1.0           13
#
#    WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  WindSpeed3pm  \
# 0           44.0          13          14          20.0          24.0
# 1           44.0           6          15           4.0          22.0
# 2           46.0          13          15          19.0          26.0
# 3           24.0           9           0          11.0           9.0
# 4           41.0           1           7           7.0          20.0
#
#    Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Temp9am  Temp3pm  \
# 0         71.0         22.0       1007.7       1007.1     16.9     21.8
# ...

# %%
# memilih variabel kategori
cat_cols = ['Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday', 'RainTomorrow']

# membuat dataframe baru : data_cat
data_cat = data_copy[cat_cols]

# melihat korelasi dari data_cat
corr_cat = data_cat.corr()

# inisiasi plot heatmap
plt.figure(figsize=(15,12))
sns.heatmap(corr_cat, annot=True)

# menampilkan plot
plt.show()

# %%
# menunjukkan 5 data teratas
data_cat.head()
# Out:
#    Location  WindGustDir  WindDir9am  WindDir3pm  RainToday  RainTomorrow
# 0         1           13          13          14          0             0
# 1         1           14           6          15          0             0
# 2         1           15          13          15          0             0
# 3         1            4           9           0          0             0
# 4         1           13           1           7          0             0

# %% [markdown]
# Dari <i>heatmap</i> diatas, dapat diambil kesimpulan bahwa dari 3 variabel mengenai arah angin yaitu WindDir3pm, WindDir9am, dan WindGustDir memiliki korelasi satu sama lain. Hal itu dapat menyebabkan adanya masalah multikolinearitas. Oleh karena itu, akan dipilih salah satu fitur saja yang akan digunakan dengan cara melihat variabel mana yang memiliki korelasi paling besar dengan variabel target yaitu variabel RainTomorrow. Berdasarkan <i>heatmap</i> di atas, terlihat bahwa variabel <b>WindGustDir</b> memiliki korelasi terbesar diantara 2 variabel lain yang berhubungan dengan arah angin, dengan nilai korelasi sebesar 0.051.

# %%
# memilih variabel numerikal
data_num = data_copy.drop(['Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday'], axis=1)

# membuat korelasi
corr = data_num.corr()

# inisiasi plot heatmap
plt.figure(figsize=(15,12))
sns.heatmap(corr, annot=True)

# menampilkan plot
plt.show()

# %% [markdown]
# Dari <i>heatmap</i> diatas, dapat diambil kesimpulan bahwa :
# - Terdapat 4 variabel yang berkaitan dengan Temperatur, yaitu MinTemp, MaxTemp, Temp9am, dan Temp3pm. Variabel Temp9am dan Temp3pm memiliki korelasi paling besar dengan RainTomorrow dimana 2 variabel ini berkorelasi negatif sebesar 0.2. Variabel <b>Temp3pm</b> memiliki korelasi terbesar dengan variabel Raintomorrow.
# - WindGustSpeed, WindSpeed9am, dan WindSpeed3pm adalah variabel yang berkaitan dengan kecepatan angin. Variabel <b>WindGustSpeed</b> memiliki korelasi terbesar dengan variabel target atau variabel RainTomorrow dengan korelasi sebesar 0.24.
# - Terdapat 2 variabel mengenai kelembaban yaitu Humidity9am dan Humidity3pm. Variabel <b>Humidity3pm</b> memiliki korelasi terbesar dengan variabel RainTomorrow sebesar 0.45.
# - Pressure9am dan Pressure3pm adalah variabel yang berkaitan dengan tekanan. Diantara 2 variabel ini, variabel Pressure9am memiliki korelasi terbesar dengan variabel target atau variabel RainTomorrow, dimana variabel <b>Pressure9am</b> memiliki korelasi negatif sebesar 0.24.

# %%
# mengambil fitur-fitur yang akan digunakan
data_clean = data_clean1[['Location', 'Temp3pm', 'Rainfall', 'WindGustSpeed', 'WindGustDir',
                         'Humidity3pm', 'Pressure9am', 'RainToday', 'RainTomorrow']]
data_clean
# Out:
#        Location  Temp3pm  Rainfall  WindGustSpeed WindGustDir  Humidity3pm  \
# 0        Albury     21.8       0.6           44.0           W         22.0
# 1        Albury     24.3       0.0           44.0         WNW         25.0
# 2        Albury     23.2       0.0           46.0         WSW         30.0
# 3        Albury     26.5       0.0           24.0          NE         16.0
# 4        Albury     29.7       1.0           41.0           W         33.0
# ...         ...      ...       ...            ...         ...          ...
# 145454    Uluru     20.9       0.0           31.0           E         27.0
# 145455    Uluru     22.4       0.0           31.0           E         24.0
# 145456    Uluru     24.5       0.0           22.0         NNW         21.0
# 145457    Uluru     26.1       0.0           37.0           N         24.0
# 145458    Uluru     26.0       0.0           28.0          SE         24.0
#
#         Pressure9am RainToday RainTomorrow
# ...

# %% [markdown]
# ### Data Exploration Each Feature

# %% [markdown]
# #### Location

# %%
# Melihat lokasi dengan rincian hari ini dan besok hujan
data_loc1 = pd.DataFrame(data_clean[(data_clean['RainToday']=='Yes') & (data_clean['RainTomorrow']=='Yes')].groupby(['Location'])['Location'].count().sort_values(ascending=False))
data_loc1
# Out:
#                   Location
# Location
# Portland               600
# Cairns                 562
# Darwin                 498
# Witchcliffe            475
# MountGambier           460
# Dartmoor               450
# Walpole                445
# CoffsHarbour           403
# NorahHead              401
# GoldCoast              394
# NorfolkIsland          387
# MountGinini            362
# SydneyAirport          361
# Ballarat               341
# Wollongong             321
# Perth                  306
# Sydney                 303
# Adelaide               303
# Brisbane               291
# Watsonia               275
# Hobart                 272
# PerthAirport           270
# Williamtown            262
# Launceston             255
# Albury                 249
# Nuriootpa              246
# Townsville             245
# MelbourneAirport       227
# Penrith                222
# Sale                   222
# BadgerysCreek          221
# Melbourne              215
# Bendigo                209
# ...

# %%
# Visualisasi lokasi yang memiliki rincian hari ini dan besok hujan
data_loc1.plot(kind = 'bar', 
                    figsize=(20,10), 
                    color='green',
                    legend = False)

plt.title('Plot Jumlah Terjadinya Hujan Hari Ini dan Besok Berdasarkan Lokasi', fontsize = 15)
# membuat nama xlabel
plt.xlabel('Lokasi', fontsize = 15, color = "black")
# membuat nama ylabel
plt.ylabel('Jumlah', fontsize = 15, color = "black")

# menampilkan bar chart
plt.show()

# %%
# Melihat lokasi dengan rincian hari ini tidak hujan dan besok hujan
data_loc2 = pd.DataFrame(data_clean[(data_clean['RainToday']=='No') & (data_clean['RainTomorrow']=='Yes')].groupby(['Location'])['Location'].count().sort_values(ascending=False))
data_loc2
# Out:
#                   Location
# Location
# NorfolkIsland          497
# Hobart                 468
# Portland               467
# MountGambier           423
# Walpole                421
# Ballarat               417
# Watsonia               414
# MelbourneAirport       413
# SydneyAirport          391
# Dartmoor               380
# NorahHead              373
# Brisbane               371
# CoffsHarbour           360
# Sale                   357
# Wollongong             355
# Cairns                 348
# MountGinini            342
# GoldCoast              342
# Witchcliffe            329
# Adelaide               323
# Launceston             319
# Darwin                 319
# Canberra               319
# Perth                  314
# WaggaWagga             311
# Nuriootpa              308
# Bendigo                308
# Melbourne              307
# SalmonGums             299
# Sydney                 293
# PerthAirport           286
# Albury                 280
# BadgerysCreek          273
# ...

# %%
# Visualisasi lokasi yang memiliki rincian hari ini tidak hujan dan besok hujan
data_loc2.plot(kind = 'bar', 
                    figsize=(20,10), 
                    color='green',
                    legend = False)

plt.title('Plot Jumlah Kejadian Tidak Hujan Hari Ini dan Hujan Besok Berdasarkan Lokasi', fontsize = 15)
# membuat nama xlabel
plt.xlabel('Lokasi', fontsize = 15, color = "black")
# membuat nama ylabel
plt.ylabel('Jumlah', fontsize = 15, color = "black")

# menampilkan bar chart
plt.show()

# %%
# Melihat lokasi dengan rincian hari ini hujan dan besok tidak hujan
data_loc3 = pd.DataFrame(data_clean[(data_clean['RainToday']=='Yes') & (data_clean['RainTomorrow']=='No')].groupby(['Location'])['Location'].count().sort_values(ascending=False))
data_loc3

# %%
# Visualisasi lokasi yang memiliki rincian hari ini hujan dan besok tidak hujan
data_loc3.plot(kind = 'bar', 
                    figsize=(20,10), 
                    color='green',
                    legend = False)

plt.title('Plot Jumlah Kejadian Hujan Hari Ini dan Tidak Hujan Besok Berdasarkan Lokasi', fontsize = 15)
# membuat nama xlabel
plt.xlabel('Lokasi', fontsize = 15, color = "black")
# membuat nama ylabel
plt.ylabel('Jumlah', fontsize = 15, color = "black")

# menampilkan bar chart
plt.show()

# %%
# Melihat lokasi dengan rincian hari ini tidak hujan dan prediksi besok tidak akan hujan
data_loc4 = pd.DataFrame(data_clean[(data_clean['RainToday']=='No') & (data_clean['RainTomorrow']=='No')].groupby(['Location'])['Location'].count().sort_values(ascending=False))
data_loc4

# %%
# Visualisasi lokasi yang memiliki rincian hari ini dan besok tidak hujan
data_loc4.plot(kind = 'bar', 
                    figsize=(20,10), 
                    color='green',
                    legend = False)

plt.title('Plot Jumlah Kejadian Tidak Hujan Hari Ini dan Besok Berdasarkan Lokasi', fontsize = 15)
# membuat nama xlabel
plt.xlabel('Lokasi', fontsize = 15, color = "black")
# membuat nama ylabel
plt.ylabel('Jumlah', fontsize = 15, color = "black")

# menampilkan bar chart
plt.show()

# %% [markdown]
# <b>Kesimpulan</b>
#
# Pada 4 plot diatas, masing - masing memiliki 4 kondisi, diantaranya :
# 1. Hari ini dan besok hujan, pada kondisi ini wilayah Portland memiliki jumlah terbanyak sebesar 600 kejadian.
# 2. Hari ini tidak hujan dan besok hujan, pada kondisi ini wilayah Norfolkisland memiliki jumlah terbanyak sebesar 497 kejadian
# 3. Hari ini hujan dan besok tidak hujan, pada kondisi ini wilayah Norflokisland memiliki jumlah terbanyak sebesar 503 kejadian
# 4. Hari ini dan besok tidak hujan, pada kondisi ini wilayah Woomera memiliki jumlah terbanyak sebesar 2568 kejadian
#
# Sehingga, dapat disimpulkan kejadian yang paling sering terjadi adalah kondisi dimana hari ini dan besok tidak hujan terutama di wilayah Woomera.

# %% [markdown]
# #### Temp3pm

# %%
# Melihat data temperatur pada pukul 9 pagi
data_temp=pd.DataFrame(data_clean['Temp3pm'])

# Menunjukkan 10 data teratas
data_temp.head(10)

# %%
# Visualisasi data menggunakan histogram
sns.histplot(data_temp, kde=True)
plt.title("Temperature 3pm")
plt.show()

# %%
# melihat sebaran temperatur menggunakan box plot
sns.boxenplot(data_temp['Temp3pm'])

# %%
# Menampilkan statistika deskriptif dari data
data_temp.describe()

# %%
# melihat Central tendency dari data temperatur pukul 9 pagi
data_temp['Temp3pm'].mode()

# %% [markdown]
# <b>Kesimpulan</b>
#
# Dapat dilihat bahwa temperatur pada jam 3 sore untuk setiap hari berkisar diantara -5.4 derajat hingga 46.7 derajat dengan rata - rata 21.891956, dan temperatur yang paling sering terjadi adalah 21.1 derajat

# %% [markdown]
# #### Pengaruh Humidity3pm dan Pressure9am terhadap Rainfall

# %% [markdown]
# ##### Humidity dan Rainfall

# %%
# inisiasi scatter plot menggunakan fitur humidity3pm dan rainfall
data_clean.plot(kind='scatter',x='Humidity3pm', y='Rainfall',
               figsize=(10,6))

# membuat judul plot
plt.title('Humidity vs Rainfall')

# menampilkan plot
plt.show()

# %% [markdown]
# <b>Kesimpulan</b>
#
# Berdasarkan scatter plot diatas, dapat disimpulkan bahwa semakin tinggi persentase kelembaban pada pukul 3 sore, maka curah hujan pada hari itu juga akan semakin tinggi.

# %% [markdown]
# ##### Pressure dan rainfall

# %%
# inisiasi scatter plot menggunakan fitur pressure9am dan rainfall
data_clean.plot(kind='scatter',x='Pressure9am', y='Rainfall',
               figsize=(10,6))

# membuat judul plot
plt.title('Pressure vs Rainfall')

# menampilkan plot
plt.show()

# %% [markdown]
# <b>Kesimpulan</b>
#
# Berdasarkan scatter plot diatas, dapat disimpulkan bahwa ketika tekanan udara sekitar 1000 sampai dengan 1020 hpa, curah hujan akan semakin tinggi. Namun, saat tekanan udara naik dari 1010 hingga 1040, curah hujan terlihat menurun.

# %% [markdown]
# #### WindGustDir

# %%
# membuat dataframe yang berisi arah angin ketika besok hujan dan tidak
yes=pd.DataFrame(data_clean[data_clean['RainTomorrow']=='Yes'].groupby(['WindGustDir'])['WindGustDir'].count())
yes.rename(columns={'WindGustDir':'Yes'}, inplace=True)
no=pd.DataFrame(data_clean[data_clean['RainTomorrow']=='No'].groupby(['WindGustDir'])['WindGustDir'].count())
no.rename(columns={'WindGustDir':'No'}, inplace=True)
data_Wind=pd.concat([yes,no], axis=1).reset_index()
data_Wind

# %%
# variabel yang akan digunakan pada plot
x = data_Wind['WindGustDir']
y1 = data_Wind['Yes']
y2 = data_Wind['No']

# inisiasi plot
plt.figure(figsize=(12,7))
plt.bar(x, y1, color='b')
plt.bar(x, y2, bottom=y1, color='c')

# membuat judul pada plot
plt.title('Pengaruh arah mata angin terhadap terjadinya hujan atau tidak pada esok hari')

# menampilkan plot
plt.show()

# %% [markdown]
# <b>Kesimpulan</b>
#
# Berdasarkan plot diatas, dapat disimpulkan bahwa kemungkinan terjadinya hujan di esok hari tidak dipengaruhi oleh arah mata angin, karena untuk setiap arah mata angin lebih banyak menunjukkan tidak terjadinya hujan. Namun, seringnya terjadi hujan di esok hari ketika angin mengarah ke barat dan utara.

# %% [markdown]
# #### WindGustSpeed

# %%
# Melihat data mengenai kecepatan angin
data_speed=pd.DataFrame(data_clean['WindGustSpeed'])

# Menunjukkan 5 data teratas
data_speed.head()

# %%
# melihat statistika deskriptif dari fitur WindGustSpeed
data_speed.describe()

# %%
# melihat sebaran kecepatan angin menggunakan box plot
sns.boxplot(data_speed['WindGustSpeed'])

# %% [markdown]
# <b>Kesimpulan</b>
#
# Berdasarkan plot di atas dapat diambil kesimpulan bahwa kecepatan angin yang paling tinggi dalam km/jam selama 24 jam sebelum jam 12 malam hari itu umumnya berada pada di sekitar 0 hingga 70 km/jam, dengan rata rata kecepatan angin sebesar 40.685280. Namun terdapat data yang menunjukkan kecepatan angin berada di atas 70 km/jam hingga 135 km/jam.

# %% [markdown]
# ## Data Preprocessing

# %%
# menunjukkan 5 data teratas
data_copy.head()

# %%
# menghapus kolom-kolom yang tidak digunakan
data_pred = data_copy.drop(['Date', 'MinTemp', 'MaxTemp', 'WindDir9am',
                           'WindDir3pm', 'WindSpeed9am', 'WindSpeed3pm',
                           'Humidity9am', 'Pressure3pm', 'Temp9am'], axis=1)

# menampilkan 5 data teratas
data_pred.head()

# %%
# Memisahkan variabel independen dan dependen
X = data_pred.drop(columns='RainTomorrow')
y = data_pred['RainTomorrow']

# Membagi data untuk training dan testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
# Melihat jumlah data training dan data testing
print(X_train.shape)
print(X_test.shape)

# %%
# melihat jumlah baris dan kolom dari data
data_clean.shape

# %% [markdown]
# Dari 12370 data, data dibagi menjadi 2 untuk dijadikan data training dan data testing dengan proporsi data training sebesar 70% atau sejumlah 86597 data dan data testing sebesar 30% atau sejumlah 37113 data.

# %% [markdown]
# ### Data Standardization

# %% [markdown]
# Berdasarkan box plot yang telah ditampilkan di Data Visualization, terlihat ada beberapa fitur yang memiliki outlier atau pencilan. Untuk mengatasi hal tersebut, kita dapat melakukan transformasi data, salah satunya ke skala standar baku.

# %%
# melakukan standarisasi data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %% [markdown]
# ## Generating Model

# %% [markdown]
# ### Logistic Regission

# %% [markdown]
# #### Defining Model

# %%
# membuat variabel model_lr sebagai instance dari LogisticRegression
model_lr=LogisticRegression(solver='liblinear', random_state=0)

# %% [markdown]
# #### Model Training

# %%
model_lr.fit(X_train,y_train)

# %%
# Memeriksa output model 
model_lr.classes_

# %%
# Memeriksa intercept model dan koefisien model
print(model_lr.intercept_, model_lr.coef_)

# %% [markdown]
# #### Model Evaluation

# %%
# Memeriksa performa model dengan melihat probabilitas
model_lr.predict_proba(X_train)

# %%
# Testing model
y_pred_lr=model_lr.predict(X_test)

# %%
# Melihat nilai akurasi
print('Train Score:',model_lr.score(X_train, y_train))
print('Test Score:',model_lr.score(X_test, y_test))

# %% [markdown]
# Diperoleh nilai akurasi untuk pelatihan data, yaitu 0.842. Sedangkan nilai akurasi untuk pengujian data sebesar 0.839

# %% [markdown]
# #### Confusion Matrix

# %%
# Visualisasi confusion matrix
cm = confusion_matrix(y_test,y_pred_lr)

fig, ax= plt.subplots(figsize=(8,8))
ax.imshow(cm)
ax.grid(False)
ax.xaxis.set(ticks=(0,1),
             ticklabels=('Predict 0','Predict 1'))
ax.yaxis.set(ticks=(0,1),
             ticklabels=('Actual 0', 'Actual 1'))
ax.set_ylim(1.5,-0.5)
for i in range(2):
    for j in range(2):
        ax.text(j, i, cm[i,j], ha='center', va='center',
               color='red')

# menampilkan plot
plt.show()

# %%
# menampilkan classifier report
print(classification_report(y_test, y_pred_lr))

# %% [markdown]
# <b>Kesimpulan:</b>\
# Berdasarkan confusion matrix di atas, terlihat banyaknya nilai TP (True Positive) adalah 3847, FP (False Positive) adalah 1514, FN (False Negative) adalah 4450, dan TN (True Negative) adalah 27302.

# %% [markdown]
# #### Find The Best Features

# %%
# Melihat importance feature
importance=model_lr.coef_[0]
sorted_index=np.argsort(importance)
labels=X.columns[sorted_index]
data_importance=pd.DataFrame({'Feature Name': labels,
                          'Feature Importance' : importance[sorted_index]})
data_importance=data_importance.sort_values(by=['Feature Importance'], ascending=False)
data_importance

# %%
# inisiasi bar plot
sns.barplot(x=data_importance['Feature Importance'],
           y=data_importance['Feature Name'])

# membuat judul plot
plt.title('Importance Features', fontsize=15)

# menampilkan plot
plt.show()

# %% [markdown]
# Dari nilai koefisien masing-masing feature di atas, beberapa feature hampir tidak menerangkan apakah besok terjadi hujan atau tidak karena nilai koefisien hanyalah sebesar 0.0x. Feature tersebut di antaranya, RainToday, Temp3pm, Rainfall, WindGustDir, dan Location. Oleh karena itu, feature-feature tersebut akan dihapus untuk melihat apakah nilai akurasi akan meningkat apabila feature dihapus.

# %%
# Membuat data frame baru dengan menghapus variabel yang tidak dibutuhkan
data_pred2=data_pred.drop(columns=['Temp3pm','Rainfall',
                              'WindGustDir','Location'])

# menampilkan 5 data teratas
data_pred2.head()

# %%
# Memisahkan variabel independen dan dependen
X2 = data_pred2.drop(columns=['RainTomorrow'])
y2 = data_pred2['RainTomorrow']

# Membagi data untuk training dan testing
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, test_size=0.3, random_state=0)

# %%
# Standarisasi data
scaler = StandardScaler()
X_train2 = scaler.fit_transform(X_train2)
X_test2 = scaler.fit_transform(X_test2)

# %%
# Membuat model 
model_lr2=LogisticRegression(solver='liblinear', random_state=0)
model_lr2.fit(X_train2, y_train2)

# %%
# Mengevaluasi model
print("Train score:",model_lr2.score(X_train2, y_train2))
print("Test score:",model_lr2.score(X_test2, y_test2))

# %% [markdown]
# Tidak ada perbedaan yang jauh antara nilai akurasi model pertama dan kedua. Hal itu berarti tidak ada pengaruh yang berarti ketika beberapa feature dengan koefisien sangat kecil dihapus. Hanya saja, jika dilihat dari nilai akurasi, model pertama sedikit lebih baik daripada model kedua.

# %% [markdown]
# #### Save Model

# %%
# Menyimpan model_lr untuk digunakan dalam deployment
pickle.dump(model_lr,open('model_lr.pkl','wb'))

# %% [markdown]
# ### Support Vector Machine (SVM)

# %% [markdown]
# #### Defining Model

# %%
# membuat variabel model_svm sebagai instance dari SVM
model_svm = svm.SVC(kernel='linear')

# %% [markdown]
# #### Model Training

# %%
model_svm.fit(X_train, y_train)

# %%
# Memeriksa intercept model dan koefisien model
print(model_svm.intercept_, model_svm.coef_)

# %% [markdown]
# #### Model Evaluation

# %%
# Testing model
y_pred_svm = model_svm.predict(X_test)

# %%
# Melihat nilai akurasi
print('Train Score:',model_svm.score(X_train, y_train))
print('Test Score:',model_svm.score(X_test, y_test))

# %% [markdown]
# Diperoleh nilai akurasi untuk pelatihan data, yaitu 0.841. Sedangkan nilai akurasi untuk pengujian data sebesar 0.839

# %% [markdown]
# #### Confusion Matrix

# %%
# Visualisasi confusion matrix
cm = confusion_matrix(y_test,y_pred_svm)

fig, ax= plt.subplots(figsize=(8,8))
ax.imshow(cm)
ax.grid(False)
ax.xaxis.set(ticks=(0,1),
             ticklabels=('Predict 0','Predict 1'))
ax.yaxis.set(ticks=(0,1),
             ticklabels=('Actual 0', 'Actual 1'))
ax.set_ylim(1.5,-0.5)
for i in range(2):
    for j in range(2):
        ax.text(j, i, cm[i,j], ha='center', va='center',
               color='red')

# menampilkan plot        
plt.show()

# %%
# menampilkan clssifier report
print(classification_report(y_test, y_pred_svm))

# %% [markdown]
# <b>Kesimpulan:</b>\
# Berdasarkan confusion matrix di atas, terlihat banyaknya nilai TP (True Positive) adalah 3602, FP (False Positive) adalah 1266, FN (False Negative) adalah 4695, dan TN (True Negative) adalah 27550.

# %% [markdown]
# #### Find The Best Features

# %%
# Melihat importance feature
importance=model_svm.coef_[0]
sorted_index=np.argsort(importance)
labels=X.columns[sorted_index]
data_importance=pd.DataFrame({'Feature Name': labels,
                          'Feature Importance' : importance[sorted_index]})
data_importance=data_importance.sort_values(by=['Feature Importance'], ascending=False)
data_importance

# %% [markdown]
# Dari nilai koefisien masing-masing feature di atas, terdapat beberapa feature yang hampir tidak menerangkan apakah besok terjadi hujan atau tidak. Hal itu dikarenakan nilai koefisien hanyalah sebesar 0.0x. Feature tersebut di antaranya, Temp3pm, WindGustDir, dan Location. Oleh karena itu, feature-feature tersebut akan dihapus untuk melihat apakah nilai akurasi akan meningkat atau tidak.

# %%
# Membuat data frame baru dengan menghapus variabel yang tidak dibutuhkan
data_pred3=data_pred.drop(columns=['Temp3pm','WindGustDir','Location'])

# menampilkan 5 data teratas
data_pred3.head()

# %%
# Memisahkan variabel independen dan dependen
X3 = data_pred3.drop(columns=['RainTomorrow'])
y3 = data_pred3['RainTomorrow']

# Membagi data untuk training dan testing
X_train3, X_test3, y_train3, y_test3 = train_test_split(X3, y3, test_size=0.3, random_state=0)

# %%
# Standarisasi data
scaler = StandardScaler()
X_train3 = scaler.fit_transform(X_train3)
X_test3 = scaler.fit_transform(X_test3)

# %%
# Membuat model 
model_svm2=LogisticRegression(solver='liblinear', random_state=0)
model_svm2.fit(X_train3, y_train3)

# %%
# Prediksi untuk data testing
y_pred_svm2 = model_svm2.predict(X_test3)

# %%
# Mengevaluasi model
print("Train score:",model_svm2.score(X_train3, y_train3))
print("Test score:",model_svm2.score(X_test3, y_test3))

# %% [markdown]
# Tidak ada perbedaan yang jauh antara nilai akurasi model pertama dan kedua. Hal itu berarti tidak ada pengaruh yang berarti ketika beberapa feature dengan koefisien sangat kecil dihapus. Hanya saja, jika dilihat dari nilai akurasi, model kedua sedikit lebih baik daripada model pertama.

# %% [markdown]
# #### Save Model

# %%
# Menyimpan model_svm untuk digunakan dalam deployment
pickle.dump(model_svm2,open('model_svm.pkl','wb'))

# %% [markdown]
# ## Perbandingan Model

# %%
print('Ringkasan Evaluasi Model Logistic Regression')
print('Akurasi :', accuracy_score(y_test, y_pred_lr))
print('Presisi :', precision_score(y_test,y_pred_lr))
print('Recall :', recall_score(y_test,y_pred_lr))
print('F1 Score :', f1_score(y_test,y_pred_lr))

print('Ringkasan Evaluasi Model SVM')
print('Akurasi :', accuracy_score(y_test3, y_pred_svm2))
print('Presisi :', precision_score(y_test3,y_pred_svm2))
print('Recall :', recall_score(y_test3,y_pred_svm2))
print('F1 Score :', f1_score(y_test3,y_pred_svm2))

# %% [markdown]
# **Dari proses generating 2 model, yaitu Logistic Regression dan SVM, kita dapat mengetahui bahwa:**
# - Nilai akurasi dari model Logistic Regression dan SVM tidak jauh berbeda, keduanya memiliki nilai akurasi sebesar 84% yang mana kedua hasil tersebut cukup baik untuk dilakukan prediksi hujan di Australia
# - Untuk nilai Akurasi, Presisi, dan F1 Score model SVM lebih unggul daripada model Logistic Regression, sedangkan untuk nilai Recall model Logistic Regression lebih unggul daripada model SVM. Hanya saja proses klasifikasi dengan SVM memakan waktu yang lebih lama dibandingkan Logistic Regression.
# - Dari kedua metode klasifikasi, dipilih SVM karena nilai akurasi model SVM sedikit lebih unggul dibandingkan Logistic Regression

# %% [markdown]
# ## Inference Model

# %%
#prediksi hujan dengan input diluar dataset
CurahHujan=float(input('Curah Hujan (mm):'))
KecepatanAngin=float(input('Kecepatan Angin (km/h):'))
Kelembaban=float(input('Kelembaban Udara (%):'))
TekananUdara=float(input('Tekanan Udara (hpa) :'))
HariIniHujan=input('Hari ini hujan? (yes/no)')
features=[CurahHujan,KecepatanAngin,Kelembaban,TekananUdara]
        
if HariIniHujan=='yes':
    features.append(1)
elif HariIniHujan=='no':
    features.append(0)
    
pred=model_svm2.predict([features])

if pred==1:
    prediction='akan hujan'
elif pred==0:
    prediction='tidak akan hujan'
print('Diprediksi besok',prediction)

# %% [markdown]
# ## Kesimpulan

# %% [markdown]
# Berdasarkan analisis yang telah dilakukan, diperoleh beberapa kesimpulan, yaitu sebagai berikut:
# - Pada dataset terdapat 22 feature yang diperkirakan dapat mempengaruhi apakah besok terjadi hujan atau tidak di 9 kota di Australia
# - Dari 4 jenis kejadian apakah hari ini dan besok hujan atau tidak, yang paling sering terjadi adalah kejadian di mana hari ini dan besok tidak hujan. Wilayah dengan kejadian hari ini dan besok tidak hujan paling sering terjadi adalah kota Woomera.
# - Semakin tinggi kelembaban pada pukul 3 sore, maka curah hujan pada hari itu juga akan semakin tinggi. Sedangkan, jika dilihat dari tekanan udara, curah hujan akan tinggi apabila tekanan udara mencapai nilai tertentu.
# - Beberapa feature numerik memiliki nilai outlier sehingga perlu melakukan standarisasi data.
# - Model yang digunakan untuk prediksi adalah model Logistic Regression dan model SVM.
# - Fitur yang digunakan dalam pemodelan adalah `Rainfall`, `WindGustSpeed`, `Humidity3pm`, `Pressure3pm`, `RainToday` dengan targetnya adalah `RainTomorrow`.
# - Nilai akurasi antara model Logistic Regression dan SVM menunjukkan hasil yang tidak jauh berbeda. Namun, model yang dipilih adalah model SVM karena untuk nilai akurasi, presisi, dan F1 Score model SVM sedikit lebih unggul dibandingkan model Logistic Regression.
# - Model SVM memiliki nilai akurasi sebesar 84% yang mana hasil tersebut cukup baik untuk dilakukan prediksi hujan di Australia.
